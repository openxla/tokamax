# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/openxla/tokamax/blob/main/tokamax_demo.ipynb)

# %% [markdown]
# Demo coming soon!
